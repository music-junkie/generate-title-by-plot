# %%
import json
import requests

import time

import pandas as pd
import numpy as np

# %%
from IPython.display import display, clear_output

result_dict = []
for page in range(1,10000):
        
    payload = {'chrono': 'news', 'locale': 'ru', 'page': page, 'per_page':'24'}    
    url = 'https://meduza.io/api/v3/search'

    response = requests.get(url, params=payload)    

    for i in response.json()['documents']:
        result_dict.append(response.json()['documents'][i])

    time.sleep(2)

    clear_output(wait=True)
    display(f'Page: {page}, count: {len(result_dict)}')

    if response.json()['has_next'] != True:
        break
# Out:
# 'Page: 1835, count: 44040'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-07867348815c> in <module>
#      12         result_dict.append(response.json()['documents'][i])
#      13
# ---> 14     time.sleep(2)
#      15
#      16     clear_output(wait=True)
#
# KeyboardInterrupt:

# %%
with open('data/data.json', 'w') as outfile:
    json.dump(result_dict, outfile)

# %%
df = pd.read_json('data/data.json')

# %%
df.head()
# Out:
#    with_banners  version                                                url  \
# 0           1.0        1  short/2020/12/14/the-sunday-times-napisala-o-p...
# 1           1.0        1  short/2020/12/14/kak-glava-roskosmosa-otreagir...
# 2           1.0        2  shapito/2020/12/14/na-glazah-u-deputata-novich...
# 3           0.0        5  news/2020/12/14/v-rossii-vyyavili-27-328-novyh...
# 4           1.0        5  news/2020/12/14/v-moskve-nachalsya-sud-nad-pol...
#
#                                                title  \
# 0  The Sunday Times написала о повторной попытке ...
# 1  Как глава «Роскосмоса» отреагировал на запуск ...
# 2  «На глазах у депутата новичок вырубил Алексея,...
# 3  В России выявили 27 328 новых случаев COVID-19...
# 4  В Москве начался суд над полицейскими, подкину...
#
#                                      tag  \
# 0        {'path': '', 'name': 'новости'}
# 1        {'path': '', 'name': 'новости'}
# 2  {'path': 'shapito', 'name': 'шапито'}
# 3        {'path': '', 'name': 'новости'}
# 4        {'path': '', 'name': 'новости'}
#
#                                               source  \
# 0                                 {'name': 'Meduza'}
# 1                                 {'name': 'Meduza'}
# 2  {'url': 'https://pdmnews.ru/18520/', 'trust': ...
# 3  {'url': 'https://xn--80aesfpebagmfblc0a.xn--p1...
# 4  {'url': 'https://meduza.io/', 'trust': 0, 'quo...
#
#                                         second_title  pushed  \
# 0                                                        0.0
# 1                                                        0.0
# 2  В полуфинале Высшей лиги КВН пошутили про отра...     0.0
# 3                                                NaN     0.0
# 4                                                NaN     0.0
#
#          published_at    pub_date  ... hide_header table_of_contents  \
# 0 2020-12-14 10:13:34  2020-12-14  ...         NaN               NaN
# 1 2020-12-14 08:39:39  2020-12-14  ...         NaN               NaN
# 2 2020-12-14 10:24:04  2020-12-14  ...         NaN               NaN
# 3 2020-12-14 08:02:44  2020-12-14  ...         NaN               NaN
# 4 2020-12-14 09:34:00  2020-12-14  ...         NaN               NaN
#
#   chapters_count subject  mail  promo_url promo_image hide_on_mobile  \
# 0            NaN     NaN   NaN        NaN         NaN            NaN
# 1            NaN     NaN   NaN        NaN         NaN            NaN
# 2            NaN     NaN   NaN        NaN         NaN            NaN
# 3            NaN     NaN   NaN        NaN         NaN            NaN
# 4            NaN     NaN   NaN        NaN         NaN            NaN
#
#   documents allowed
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
#
# [5 rows x 32 columns]
